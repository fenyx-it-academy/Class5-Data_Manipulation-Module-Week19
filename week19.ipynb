# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import re

import warnings
warnings.filterwarnings('ignore')
warnings.warn('this will not show')
sns.set(style='darkgrid')
# %matplotlib inline

# %% [markdown]
# 1. Read the dataset as a dataframe. Create a copy.

# %%
data=pd.read_csv('weatherAUS.csv')
df=data.copy()
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %% [markdown]
# 2. Find out the describe and info attributes of the dataframe.

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %% [markdown]
# 3. find out the shape and the size of the dataset

# %%
df.size
# Out:
# 3345580

# %%
df.shape
# Out:
# (145460, 23)

# %% [markdown]
# 4. find out the types values of the columns

# %%
df3=pd.DataFrame(df.dtypes,columns=['Title'])
df3
# Out:
#                  Title
# Date            object
# Location        object
# MinTemp        float64
# MaxTemp        float64
# Rainfall       float64
# Evaporation    float64
# Sunshine       float64
# WindGustDir     object
# WindGustSpeed  float64
# WindDir9am      object
# WindDir3pm      object
# WindSpeed9am   float64
# WindSpeed3pm   float64
# Humidity9am    float64
# Humidity3pm    float64
# Pressure9am    float64
# Pressure3pm    float64
# Cloud9am       float64
# Cloud3pm       float64
# Temp9am        float64
# Temp3pm        float64
# RainToday       object
# RainTomorrow    object

# %% [markdown]
# 5. find out the non null counts of the columns

# %%
df4=pd.DataFrame(df.notnull().sum(),columns=['Notnull'])
df4
# Out:
#                Notnull
# Date            145460
# Location        145460
# MinTemp         143975
# MaxTemp         144199
# Rainfall        142199
# Evaporation      82670
# Sunshine         75625
# WindGustDir     135134
# WindGustSpeed   135197
# WindDir9am      134894
# WindDir3pm      141232
# WindSpeed9am    143693
# WindSpeed3pm    142398
# Humidity9am     142806
# Humidity3pm     140953
# Pressure9am     130395
# Pressure3pm     130432
# Cloud9am         89572
# Cloud3pm         86102
# Temp9am         143693
# Temp3pm         141851
# RainToday       142199
# RainTomorrow    142193

# %% [markdown]
# 6. find out the null counts of the columns

# %%
df5=pd.DataFrame(df.isnull().sum(),columns=['Null'])
df5
# Out:
#                 Null
# Date               0
# Location           0
# MinTemp         1485
# MaxTemp         1261
# Rainfall        3261
# Evaporation    62790
# Sunshine       69835
# WindGustDir    10326
# WindGustSpeed  10263
# WindDir9am     10566
# WindDir3pm      4228
# WindSpeed9am    1767
# WindSpeed3pm    3062
# Humidity9am     2654
# Humidity3pm     4507
# Pressure9am    15065
# Pressure3pm    15028
# Cloud9am       55888
# Cloud3pm       59358
# Temp9am         1767
# Temp3pm         3609
# RainToday       3261
# RainTomorrow    3267

# %% [markdown]
# 7. find out the unique counts of columns

# %%
df6=pd.DataFrame(df.nunique(),columns=['Unique'])
df6
# Out:
#                Unique
# Date             3436
# Location           49
# MinTemp           389
# MaxTemp           505
# Rainfall          681
# Evaporation       358
# Sunshine          145
# WindGustDir        16
# WindGustSpeed      67
# WindDir9am         16
# WindDir3pm         16
# WindSpeed9am       43
# WindSpeed3pm       44
# Humidity9am       101
# Humidity3pm       101
# Pressure9am       546
# Pressure3pm       549
# Cloud9am           10
# Cloud3pm           10
# Temp9am           441
# Temp3pm           502
# RainToday           2
# RainTomorrow        2

# %% [markdown]
# 8. Merge the dataframes

# %%
merge_df=pd.concat([df3,df4,df5,df6],axis=1)
merge_df
# Out:
#                  Title  Notnull   Null  Unique
# Date            object   145460      0    3436
# Location        object   145460      0      49
# MinTemp        float64   143975   1485     389
# MaxTemp        float64   144199   1261     505
# Rainfall       float64   142199   3261     681
# Evaporation    float64    82670  62790     358
# Sunshine       float64    75625  69835     145
# WindGustDir     object   135134  10326      16
# WindGustSpeed  float64   135197  10263      67
# WindDir9am      object   134894  10566      16
# WindDir3pm      object   141232   4228      16
# WindSpeed9am   float64   143693   1767      43
# WindSpeed3pm   float64   142398   3062      44
# Humidity9am    float64   142806   2654     101
# Humidity3pm    float64   140953   4507     101
# Pressure9am    float64   130395  15065     546
# Pressure3pm    float64   130432  15028     549
# Cloud9am       float64    89572  55888      10
# Cloud3pm       float64    86102  59358      10
# ...

# %% [markdown]
# 9. Lovercase all columns names

# %%
df7=df.columns.str.lower()
df7
# Out:
# Index(['date', 'location', 'mintemp', 'maxtemp', 'rainfall', 'evaporation',
#        'sunshine', 'windgustdir', 'windgustspeed', 'winddir9am', 'winddir3pm',
#        'windspeed9am', 'windspeed3pm', 'humidity9am', 'humidity3pm',
#        'pressure9am', 'pressure3pm', 'cloud9am', 'cloud3pm', 'temp9am',
#        'temp3pm', 'raintoday', 'raintomorrow'],
#       dtype='object')

# %% [markdown]
# 10. Replace

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df['RainToday'].replace(['Yes','No'],['Rain','NoRain'],inplace=True)
df['RainTomorrow'].replace(['Yes','No'],['Rain','NoRain'],inplace=True)
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %% [markdown]
# 11. Date Change

# %%
import pandas as pd
data=pd.read_csv('weatherAUS.csv')
df=data.copy()

df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df['Date']=pd.to_datetime(df['Date'])

df['Date']
# Out:
# 0        2008-01-12
# 1        2008-02-12
# 2        2008-03-12
# 3        2008-04-12
# 4        2008-05-12
#             ...
# 145455   2017-06-21
# 145456   2017-06-22
# 145457   2017-06-23
# 145458   2017-06-24
# 145459   2017-06-25
# Name: Date, Length: 145460, dtype: datetime64[ns]

# %%
df['Date']=df['Date'].dt.strftime("%d-%m-%Y")

df['Date']
# Out:
# 0         12-01-2008
# 1         12-02-2008
# 2         12-03-2008
# 3         12-04-2008
# 4         12-05-2008
#              ...
# 145455    21-06-2017
# 145456    22-06-2017
# 145457    23-06-2017
# 145458    24-06-2017
# 145459    25-06-2017
# Name: Date, Length: 145460, dtype: object

# %% [markdown]
# 12. Add new column

# %%
import pandas as pd
data=pd.read_csv('weatherAUS.csv')
df=data.copy()
df['Difference']=df['MaxTemp']-df['MinTemp']
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  \
# ...

# %% [markdown]
# 13. Remove columns

# %%
df.drop(['Evaporation','Sunshine'],axis=1, inplace=True)
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall WindGustDir  \
# 0       2008-12-01   Albury     13.4     22.9       0.6           W
# 1       2008-12-02   Albury      7.4     25.1       0.0         WNW
# 2       2008-12-03   Albury     12.9     25.7       0.0         WSW
# 3       2008-12-04   Albury      9.2     28.0       0.0          NE
# 4       2008-12-05   Albury     17.5     32.3       1.0           W
# ...            ...      ...      ...      ...       ...         ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0           E
# 145456  2017-06-22    Uluru      3.6     25.3       0.0         NNW
# 145457  2017-06-23    Uluru      5.4     26.9       0.0           N
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          SE
# 145459  2017-06-25    Uluru     14.9      NaN       0.0         NaN
#
#         WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# ...

# %% [markdown]
# 14. Most rainy day

# %% [markdown]
# 15. Filter out all the data for city Albury

# %%
df.loc[df['Location']=='Albury'].sort_values(by = 'MaxTemp')
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 2328  2015-07-15   Albury      4.4      6.8      10.0          NaN       NaN
# 2675  2016-06-26   Albury     -1.3      7.5       0.0          NaN       NaN
# 193   2009-06-12   Albury     -1.3      8.2       0.0          NaN       NaN
# 2673  2016-06-24   Albury      6.6      8.2       4.0          NaN       NaN
# 919   2011-07-08   Albury     -0.5      8.3       0.0          NaN       NaN
# ...          ...      ...      ...      ...       ...          ...       ...
# 984   2011-09-11   Albury      NaN      NaN       NaN          NaN       NaN
# 985   2011-09-12   Albury      NaN      NaN       NaN          NaN       NaN
# 1529  2013-05-07   Albury      3.9      NaN       0.0          NaN       NaN
# 2031  2014-09-21   Albury      3.4      NaN       0.0          NaN       NaN
# 2032  2014-09-22   Albury      NaN      NaN       NaN          NaN       NaN
#
# ...

# %% [markdown]
# 16. Find out Nan counts for each column

# %%
df.isna().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %% [markdown]
# 17. Remove the rows with NaN values in 'windgustdir'

# %%
df.dropna(subset=['WindGustDir'],inplace=True)
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145454  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...
