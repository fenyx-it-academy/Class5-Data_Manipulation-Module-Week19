# %%
#necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import re

#to avoid warnings
import warnings
warnings.filterwarnings('ignore')
warnings.warn("this will now show")

sns.set(style='darkgrid')
# %matplotlib inline

# %%
#1  reads downloaded csv
data=pd.read_csv('archive.zip')
data
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
#1  reads downloaded csv
data=pd.read_csv('archive.zip')
df=data.copy()
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
#2 
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
#3 shape=(rows,columns)  ,   size info=total elements)
df.shape    ,    df.size   #
# Out:
# ((145460, 23), 3345580)

# %%
df.size
# Out:
# 3345580

# %%
#4 columns ,datatypes
col_dtype=pd.DataFrame(df.dtypes,columns=["Types"])
col_dtype
# Out:
#                  Types
# Date            object
# Location        object
# MinTemp        float64
# MaxTemp        float64
# Rainfall       float64
# Evaporation    float64
# Sunshine       float64
# WindGustDir     object
# WindGustSpeed  float64
# WindDir9am      object
# WindDir3pm      object
# WindSpeed9am   float64
# WindSpeed3pm   float64
# Humidity9am    float64
# Humidity3pm    float64
# Pressure9am    float64
# Pressure3pm    float64
# Cloud9am       float64
# Cloud3pm       float64
# Temp9am        float64
# Temp3pm        float64
# RainToday       object
# RainTomorrow    object

# %%
#5 not-null counts
df_notnull=pd.DataFrame(df.notnull().sum(),columns=["Counted_nonnulls"])
df_notnull
# Out:
#                Counted_nonnulls
# Date                     145460
# Location                 145460
# MinTemp                  143975
# MaxTemp                  144199
# Rainfall                 142199
# Evaporation               82670
# Sunshine                  75625
# WindGustDir              135134
# WindGustSpeed            135197
# WindDir9am               134894
# WindDir3pm               141232
# WindSpeed9am             143693
# WindSpeed3pm             142398
# Humidity9am              142806
# Humidity3pm              140953
# Pressure9am              130395
# Pressure3pm              130432
# Cloud9am                  89572
# Cloud3pm                  86102
# Temp9am                  143693
# Temp3pm                  141851
# RainToday                142199
# RainTomorrow             142193

# %%
#6 null counts
df_null=pd.DataFrame(df.isnull().sum(),columns=["Counted_Nulls"])
df_null
# Out:
#                Counted_Nulls
# Date                       0
# Location                   0
# MinTemp                 1485
# MaxTemp                 1261
# Rainfall                3261
# Evaporation            62790
# Sunshine               69835
# WindGustDir            10326
# WindGustSpeed          10263
# WindDir9am             10566
# WindDir3pm              4228
# WindSpeed9am            1767
# WindSpeed3pm            3062
# Humidity9am             2654
# Humidity3pm             4507
# Pressure9am            15065
# Pressure3pm            15028
# Cloud9am               55888
# Cloud3pm               59358
# Temp9am                 1767
# Temp3pm                 3609
# RainToday               3261
# RainTomorrow            3267

# %%
#7
df_uniques=pd.DataFrame(df.nunique(),columns=["Counted_Uniques"])
df_uniques
# Out:
#                Counted_Uniques
# Date                      3436
# Location                    49
# MinTemp                    389
# MaxTemp                    505
# Rainfall                   681
# Evaporation                358
# Sunshine                   145
# WindGustDir                 16
# WindGustSpeed               67
# WindDir9am                  16
# WindDir3pm                  16
# WindSpeed9am                43
# WindSpeed3pm                44
# Humidity9am                101
# Humidity3pm                101
# Pressure9am                546
# Pressure3pm                549
# Cloud9am                    10
# Cloud3pm                    10
# Temp9am                    441
# Temp3pm                    502
# RainToday                    2
# RainTomorrow                 2

# %%
#8 merged 4,5,6,7
df_merged=pd.concat([col_dtype,df_notnull,df_null,df_uniques],axis=1)
df_merged
# Out:
#                  Types  Counted_nonnulls  Counted_Nulls  Counted_Uniques
# Date            object            145460              0             3436
# Location        object            145460              0               49
# MinTemp        float64            143975           1485              389
# MaxTemp        float64            144199           1261              505
# Rainfall       float64            142199           3261              681
# Evaporation    float64             82670          62790              358
# Sunshine       float64             75625          69835              145
# WindGustDir     object            135134          10326               16
# WindGustSpeed  float64            135197          10263               67
# WindDir9am      object            134894          10566               16
# WindDir3pm      object            141232           4228               16
# WindSpeed9am   float64            143693           1767               43
# ...

# %%
# # 9 Lowercase all column names
df.columns= df.columns.str.lower()
columns_T=df.head().T
columns_T
# Out:
#                         0           1           2           3           4
# date           2008-12-01  2008-12-02  2008-12-03  2008-12-04  2008-12-05
# location           Albury      Albury      Albury      Albury      Albury
# mintemp              13.4         7.4        12.9         9.2        17.5
# maxtemp              22.9        25.1        25.7        28.0        32.3
# rainfall              0.6         0.0         0.0         0.0         1.0
# evaporation           NaN         NaN         NaN         NaN         NaN
# sunshine              NaN         NaN         NaN         NaN         NaN
# windgustdir             W         WNW         WSW          NE           W
# windgustspeed        44.0        44.0        46.0        24.0        41.0
# winddir9am              W         NNW           W          SE         ENE
# winddir3pm            WNW         WSW         WSW           E          NW
# windspeed9am         20.0         4.0        19.0        11.0         7.0
# ...

# %%
# #10 change values
cols=["raintoday","raintomorrow"]
df[cols[0]].replace({"No":"NoRain","Yes":"YesRain"},inplace=True)
df[cols[1]].replace({"No":"NoRain","Yes":"YesRain"},inplace=True)
df[cols]
# Out:
#        raintoday raintomorrow
# 0         NoRain       NoRain
# 1         NoRain       NoRain
# 2         NoRain       NoRain
# 3         NoRain       NoRain
# 4         NoRain       NoRain
# ...          ...          ...
# 145455    NoRain       NoRain
# 145456    NoRain       NoRain
# 145457    NoRain       NoRain
# 145458    NoRain       NoRain
# 145459    NoRain          NaN
#
# [145460 rows x 2 columns]

# %% [markdown]
# df

# %%
# #11
df['date']=df['date'].astype('datetime64')
df['date']
# Out:
# 0        2008-12-01
# 1        2008-12-02
# 2        2008-12-03
# 3        2008-12-04
# 4        2008-12-05
#             ...
# 145455   2017-06-21
# 145456   2017-06-22
# 145457   2017-06-23
# 145458   2017-06-24
# 145459   2017-06-25
# Name: date, Length: 145460, dtype: datetime64[ns]

# %%
df['date']=df['date'].astype('datetime64').dt.strftime('%d/%m/%Y')
df['date']
# Out:
# 0         01/12/2008
# 1         02/12/2008
# 2         03/12/2008
# 3         04/12/2008
# 4         05/12/2008
#              ...
# 145455    21/06/2017
# 145456    22/06/2017
# 145457    23/06/2017
# 145458    24/06/2017
# 145459    25/06/2017
# Name: date, Length: 145460, dtype: object

# %%
#12
df['dif_max_min']=df["maxtemp"]-df["mintemp"]
df.head(5)
# Out:
#          date location  mintemp  maxtemp  rainfall  evaporation  sunshine  \
# 0  01/12/2008   Albury     13.4     22.9       0.6          NaN       NaN
# 1  02/12/2008   Albury      7.4     25.1       0.0          NaN       NaN
# 2  03/12/2008   Albury     12.9     25.7       0.0          NaN       NaN
# 3  04/12/2008   Albury      9.2     28.0       0.0          NaN       NaN
# 4  05/12/2008   Albury     17.5     32.3       1.0          NaN       NaN
#
#   windgustdir  windgustspeed winddir9am  ... humidity3pm  pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
# 2         WSW           46.0          W  ...        30.0       1007.6
# 3          NE           24.0         SE  ...        16.0       1017.6
# 4           W           41.0        ENE  ...        33.0       1010.8
#
#    pressure3pm  cloud9am  cloud3pm  temp9am  temp3pm  raintoday  raintomorrow  \
# ...

# %%
#13
df.drop(["sunshine","evaporation"],axis=1,inplace=True)
df.head().T
# Out:
#                         0           1           2           3           4
# date           01/12/2008  02/12/2008  03/12/2008  04/12/2008  05/12/2008
# location           Albury      Albury      Albury      Albury      Albury
# mintemp              13.4         7.4        12.9         9.2        17.5
# maxtemp              22.9        25.1        25.7        28.0        32.3
# rainfall              0.6         0.0         0.0         0.0         1.0
# windgustdir             W         WNW         WSW          NE           W
# windgustspeed        44.0        44.0        46.0        24.0        41.0
# winddir9am              W         NNW           W          SE         ENE
# winddir3pm            WNW         WSW         WSW           E          NW
# windspeed9am         20.0         4.0        19.0        11.0         7.0
# windspeed3pm         24.0        22.0        26.0         9.0        20.0
# humidity9am          71.0        44.0        38.0        45.0        82.0
# ...

# %%
#14 most rainy days
df_most_rainy = df.loc[df.groupby('location')['rainfall'].idxmax().values][['location','date','rainfall']].set_index('location')
df_most_rainy
# Out:
#                         date  rainfall
# location
# Adelaide          14/02/2014      75.2
# Albany            02/06/2012      49.4
# Albury            01/03/2012     104.2
# AliceSprings      28/02/2010      62.0
# BadgerysCreek     29/01/2013     116.0
# Ballarat          14/01/2011      95.0
# Bendigo           05/02/2011      66.4
# Brisbane          02/05/2015     182.6
# Cairns            12/01/2009     278.4
# Canberra          03/12/2010      87.0
# Cobar             16/02/2014      68.0
# CoffsHarbour      07/11/2009     371.0
# Dartmoor          14/01/2011      73.6
# Darwin            16/02/2011     367.6
# GoldCoast         29/04/2012     183.4
# Hobart            14/01/2015      71.6
# Katherine         27/12/2015     167.0
# Launceston        29/01/2016      88.0
# Melbourne         07/02/2011      82.2
# MelbourneAirport  01/06/2013      75.8
# Mildura           05/02/2011     155.0
# Moree             26/11/2011     113.0
# MountGambier      14/01/2011      84.6
# ...

# %%
#15
df[df["location"]=="Albury"].sort_values("maxtemp",ascending=False).head(10)
# Out:
#             date location  mintemp  maxtemp  rainfall windgustdir  \
# 68    07/02/2009   Albury     22.3     44.8       0.0         NNW
# 2904  10/02/2017   Albury     23.0     43.7       0.0         WSW
# 1783  16/01/2014   Albury     23.0     43.6       0.0           N
# 1435  05/01/2013   Albury     19.8     43.4       0.0          NW
# 62    01/02/2009   Albury     28.0     43.1       0.0          SW
# 1448  18/01/2013   Albury     18.9     43.1       0.0           W
# 44    14/01/2009   Albury     17.4     43.0       0.0          NW
# 2510  13/01/2016   Albury     20.2     43.0       0.0         WNW
# 60    30/01/2009   Albury     22.3     42.9       0.0         NNE
# 61    31/01/2009   Albury     22.0     42.7       0.0         ESE
#
#       windgustspeed winddir9am winddir3pm  windspeed9am  ...  humidity3pm  \
# 68             59.0         SE         NW           9.0  ...         11.0
# 2904           44.0        SSE          W           7.0  ...         17.0
# ...

# %%
#16 NaN counter,each column
df.isnull().sum(axis = 0)
# Out:
# date                 0
# location             0
# mintemp           1485
# maxtemp           1261
# rainfall          3261
# windgustdir      10326
# windgustspeed    10263
# winddir9am       10566
# winddir3pm        4228
# windspeed9am      1767
# windspeed3pm      3062
# humidity9am       2654
# humidity3pm       4507
# pressure9am      15065
# pressure3pm      15028
# cloud9am         55888
# cloud3pm         59358
# temp9am           1767
# temp3pm           3609
# raintoday         3261
# raintomorrow      3267
# dif_max_min       1881
# dtype: int64

# %%
#17
df.dropna(subset=['windgustdir'],inplace=True)
df
# Out:
#               date location  mintemp  maxtemp  rainfall windgustdir  \
# 0       01/12/2008   Albury     13.4     22.9       0.6           W
# 1       02/12/2008   Albury      7.4     25.1       0.0         WNW
# 2       03/12/2008   Albury     12.9     25.7       0.0         WSW
# 3       04/12/2008   Albury      9.2     28.0       0.0          NE
# 4       05/12/2008   Albury     17.5     32.3       1.0           W
# ...            ...      ...      ...      ...       ...         ...
# 145454  20/06/2017    Uluru      3.5     21.8       0.0           E
# 145455  21/06/2017    Uluru      2.8     23.4       0.0           E
# 145456  22/06/2017    Uluru      3.6     25.3       0.0         NNW
# 145457  23/06/2017    Uluru      5.4     26.9       0.0           N
# 145458  24/06/2017    Uluru      7.8     27.0       0.0          SE
#
#         windgustspeed winddir9am winddir3pm  windspeed9am  ...  humidity3pm  \
# ...

# %%
#18  Removed evaporation and sunshine columns from the dataset permanently.
df_2=data.copy()  #df hasnt evaporation,sunshine anymore,this makes a new one.
df_location=df_2.groupby('Location').agg({'Evaporation':['min','max','median'],'Sunshine':['min','max','median']})
df_location.head(5)
# Out:
#               Evaporation              Sunshine
#                       min   max median      min   max median
# Location
# Adelaide              0.0  43.4    4.2      0.0  13.9    8.4
# Albany                0.0  33.6    3.8      0.0  13.8    6.9
# Albury                NaN   NaN    NaN      NaN   NaN    NaN
# AliceSprings          0.0  50.2    8.2      0.0  13.5   10.6
# BadgerysCreek         NaN   NaN    NaN      NaN   NaN    NaN

# %%
#19
df = df[df['maxtemp'].notna()]
df[(df.location=='Perth')].sort_values(by=['maxtemp']).tail(1)["date"]
# Out:
# 122928    05/01/2015
# Name: date, dtype: object

# %%
#20
df.groupby('location').mean().head(10)
# Out:
#                  mintemp    maxtemp  rainfall  windgustspeed  windspeed9am  \
# location
# Adelaide       12.571487  22.891254  1.576076      36.499211      9.954804
# Albury          9.518588  22.629555  1.904552      32.977394      8.209720
# AliceSprings   13.151021  29.281325  0.869775      40.527443     14.751507
# BadgerysCreek  11.134270  24.014949  2.217714      33.593857      8.050206
# Ballarat        7.348670  18.267930  1.706369      44.982719     19.976024
# Bendigo         8.611841  21.625609  1.631586      38.844948     12.945630
# Brisbane       16.414122  26.436043  3.122293      28.211813      6.948238
# Cairns         21.225099  29.559550  5.701852      38.026150     15.902649
# Canberra        6.670100  20.731579  1.745920      40.071682     10.444228
# Cobar          13.131412  25.853488  1.132655      36.750590     14.679717
#
#                windspeed3pm  humidity9am  humidity3pm  pressure9am  \
# location
# ...
