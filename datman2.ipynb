# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import re

import warnings
warnings.filterwarnings('ignore')
warnings.warn('this will not show')

sns.set(style='darkgrid')
# %matplotlib inline

# %%
data = pd.read_csv('data/weatherAUS.csv.zip')#1
df = data.copy()
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.describe()#2
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
df.shape #3
# Out:
# (145460, 23)

# %%
df.size
# Out:
# 3345580

# %%
df.dtypes#4
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# dtype: object

# %%
da = pd.DataFrame(df.dtypes)
da
# Out:
#                      0
# Date            object
# Location        object
# MinTemp        float64
# MaxTemp        float64
# Rainfall       float64
# Evaporation    float64
# Sunshine       float64
# WindGustDir     object
# WindGustSpeed  float64
# WindDir9am      object
# WindDir3pm      object
# WindSpeed9am   float64
# WindSpeed3pm   float64
# Humidity9am    float64
# Humidity3pm    float64
# Pressure9am    float64
# Pressure3pm    float64
# Cloud9am       float64
# Cloud3pm       float64
# Temp9am        float64
# Temp3pm        float64
# RainToday       object
# RainTomorrow    object

# %%
df.notna().sum()#5
# Out:
# Date             145460
# Location         145460
# MinTemp          143975
# MaxTemp          144199
# Rainfall         142199
# Evaporation       82670
# Sunshine          75625
# WindGustDir      135134
# WindGustSpeed    135197
# WindDir9am       134894
# WindDir3pm       141232
# WindSpeed9am     143693
# WindSpeed3pm     142398
# Humidity9am      142806
# Humidity3pm      140953
# Pressure9am      130395
# Pressure3pm      130432
# Cloud9am          89572
# Cloud3pm          86102
# Temp9am          143693
# Temp3pm          141851
# RainToday        142199
# RainTomorrow     142193
# dtype: int64

# %%
dc = pd.DataFrame(df.notna().sum())
dc
# Out:
#                     0
# Date           145460
# Location       145460
# MinTemp        143975
# MaxTemp        144199
# Rainfall       142199
# Evaporation     82670
# Sunshine        75625
# WindGustDir    135134
# WindGustSpeed  135197
# WindDir9am     134894
# WindDir3pm     141232
# WindSpeed9am   143693
# WindSpeed3pm   142398
# Humidity9am    142806
# Humidity3pm    140953
# Pressure9am    130395
# Pressure3pm    130432
# Cloud9am        89572
# Cloud3pm        86102
# Temp9am        143693
# Temp3pm        141851
# RainToday      142199
# RainTomorrow   142193

# %%
df.isna().sum()#6
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
db = pd.DataFrame(df.isna().sum())
db
# Out:
#                    0
# Date               0
# Location           0
# MinTemp         1485
# MaxTemp         1261
# Rainfall        3261
# Evaporation    62790
# Sunshine       69835
# WindGustDir    10326
# WindGustSpeed  10263
# WindDir9am     10566
# WindDir3pm      4228
# WindSpeed9am    1767
# WindSpeed3pm    3062
# Humidity9am     2654
# Humidity3pm     4507
# Pressure9am    15065
# Pressure3pm    15028
# Cloud9am       55888
# Cloud3pm       59358
# Temp9am         1767
# Temp3pm         3609
# RainToday       3261
# RainTomorrow    3267

# %%
unique = df.nunique(dropna=False)#7
unique
# Out:
# Date             3436
# Location           49
# MinTemp           390
# MaxTemp           506
# Rainfall          682
# Evaporation       359
# Sunshine          146
# WindGustDir        17
# WindGustSpeed      68
# WindDir9am         17
# WindDir3pm         17
# WindSpeed9am       44
# WindSpeed3pm       45
# Humidity9am       102
# Humidity3pm       102
# Pressure9am       547
# Pressure3pm       550
# Cloud9am           11
# Cloud3pm           11
# Temp9am           442
# Temp3pm           503
# RainToday           3
# RainTomorrow        3
# dtype: int64

# %%
uniq = pd.DataFrame(unique)
uniq
# Out:
#                   0
# Date           3436
# Location         49
# MinTemp         390
# MaxTemp         506
# Rainfall        682
# Evaporation     359
# Sunshine        146
# WindGustDir      17
# WindGustSpeed    68
# WindDir9am       17
# WindDir3pm       17
# WindSpeed9am     44
# WindSpeed3pm     45
# Humidity9am     102
# Humidity3pm     102
# Pressure9am     547
# Pressure3pm     550
# Cloud9am         11
# Cloud3pm         11
# Temp9am         442
# Temp3pm         503
# RainToday         3
# RainTomorrow      3

# %%
pd.concat([uniq,da,db,dc],axis = 1)#8
# Out:
#                   0        0      0       0
# Date           3436   object      0  145460
# Location         49   object      0  145460
# MinTemp         390  float64   1485  143975
# MaxTemp         506  float64   1261  144199
# Rainfall        682  float64   3261  142199
# Evaporation     359  float64  62790   82670
# Sunshine        146  float64  69835   75625
# WindGustDir      17   object  10326  135134
# WindGustSpeed    68  float64  10263  135197
# WindDir9am       17   object  10566  134894
# WindDir3pm       17   object   4228  141232
# WindSpeed9am     44  float64   1767  143693
# WindSpeed3pm     45  float64   3062  142398
# Humidity9am     102  float64   2654  142806
# Humidity3pm     102  float64   4507  140953
# Pressure9am     547  float64  15065  130395
# Pressure3pm     550  float64  15028  130432
# Cloud9am         11  float64  55888   89572
# Cloud3pm         11  float64  59358   86102
# Temp9am         442  float64   1767  143693
# ...

# %%
df.columns= df.columns.str.lower()#9
df.columns
# Out:
# Index(['date', 'location', 'mintemp', 'maxtemp', 'rainfall', 'evaporation',
#        'sunshine', 'windgustdir', 'windgustspeed', 'winddir9am', 'winddir3pm',
#        'windspeed9am', 'windspeed3pm', 'humidity9am', 'humidity3pm',
#        'pressure9am', 'pressure3pm', 'cloud9am', 'cloud3pm', 'temp9am',
#        'temp3pm', 'raintoday', 'raintomorrow'],
#       dtype='object')

# %%
df["raintoday"].replace({"No": "NoRain", "Yes": "Rain"}, inplace=True)#10
df
# Out:
#               date location  mintemp  maxtemp  rainfall  evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         sunshine windgustdir  windgustspeed winddir9am  ... humidity9am  \
# ...

# %%
df["raintomorrow"].replace({"No": "NoRain", "Yes": "Rain"}, inplace=True)
df
# Out:
#               date location  mintemp  maxtemp  rainfall  evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         sunshine windgustdir  windgustspeed winddir9am  ... humidity9am  \
# ...

# %%
df['date']=pd.to_datetime(df['date'])#11
df
# Out:
#              date location  mintemp  maxtemp  rainfall  evaporation  sunshine  \
# 0      2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1      2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2      2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3      2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4      2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# ...           ...      ...      ...      ...       ...          ...       ...
# 145455 2017-06-21    Uluru      2.8     23.4       0.0          NaN       NaN
# 145456 2017-06-22    Uluru      3.6     25.3       0.0          NaN       NaN
# 145457 2017-06-23    Uluru      5.4     26.9       0.0          NaN       NaN
# 145458 2017-06-24    Uluru      7.8     27.0       0.0          NaN       NaN
# 145459 2017-06-25    Uluru     14.9      NaN       0.0          NaN       NaN
#
# ...

# %%
df['date'] = df['date'].dt.strftime('%d-%m-%Y')

# %%
df.head()
# Out:
#          date location  mintemp  maxtemp  rainfall  evaporation  sunshine  \
# 0  01-12-2008   Albury     13.4     22.9       0.6          NaN       NaN
# 1  02-12-2008   Albury      7.4     25.1       0.0          NaN       NaN
# 2  03-12-2008   Albury     12.9     25.7       0.0          NaN       NaN
# 3  04-12-2008   Albury      9.2     28.0       0.0          NaN       NaN
# 4  05-12-2008   Albury     17.5     32.3       1.0          NaN       NaN
#
#   windgustdir  windgustspeed winddir9am  ... humidity9am  humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    pressure9am  pressure3pm  cloud9am  cloud3pm  temp9am  temp3pm  raintoday  \
# ...

# %%
df['difference'] = pd.Series.abs(df['maxtemp'] - df['mintemp'])#12

# %%
df
# Out:
#               date location  mintemp  maxtemp  rainfall  evaporation  \
# 0       01-12-2008   Albury     13.4     22.9       0.6          NaN
# 1       02-12-2008   Albury      7.4     25.1       0.0          NaN
# 2       03-12-2008   Albury     12.9     25.7       0.0          NaN
# 3       04-12-2008   Albury      9.2     28.0       0.0          NaN
# 4       05-12-2008   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  21-06-2017    Uluru      2.8     23.4       0.0          NaN
# 145456  22-06-2017    Uluru      3.6     25.3       0.0          NaN
# 145457  23-06-2017    Uluru      5.4     26.9       0.0          NaN
# 145458  24-06-2017    Uluru      7.8     27.0       0.0          NaN
# 145459  25-06-2017    Uluru     14.9      NaN       0.0          NaN
#
#         sunshine windgustdir  windgustspeed winddir9am  ... humidity3pm  \
# ...

# %%
df.drop('evaporation', axis = 1, inplace = True)#13

# %%
df.drop('sunshine', axis = 1, inplace = True)

# %%
df
# Out:
#               date location  mintemp  maxtemp  rainfall windgustdir  \
# 0       01-12-2008   Albury     13.4     22.9       0.6           W
# 1       02-12-2008   Albury      7.4     25.1       0.0         WNW
# 2       03-12-2008   Albury     12.9     25.7       0.0         WSW
# 3       04-12-2008   Albury      9.2     28.0       0.0          NE
# 4       05-12-2008   Albury     17.5     32.3       1.0           W
# ...            ...      ...      ...      ...       ...         ...
# 145455  21-06-2017    Uluru      2.8     23.4       0.0           E
# 145456  22-06-2017    Uluru      3.6     25.3       0.0         NNW
# 145457  23-06-2017    Uluru      5.4     26.9       0.0           N
# 145458  24-06-2017    Uluru      7.8     27.0       0.0          SE
# 145459  25-06-2017    Uluru     14.9      NaN       0.0         NaN
#
#         windgustspeed winddir9am winddir3pm  windspeed9am  ...  humidity3pm  \
# ...

# %%
df.groupby('location').agg({'rainfall': ['max']})#14
# Out:
#                  rainfall
#                       max
# location
# Adelaide             75.2
# Albany               49.4
# Albury              104.2
# AliceSprings         62.0
# BadgerysCreek       116.0
# Ballarat             95.0
# Bendigo              66.4
# Brisbane            182.6
# Cairns              278.4
# Canberra             87.0
# Cobar                68.0
# CoffsHarbour        371.0
# Dartmoor             73.6
# Darwin              367.6
# GoldCoast           183.4
# Hobart               71.6
# Katherine           167.0
# Launceston           88.0
# Melbourne            82.2
# MelbourneAirport     75.8
# Mildura             155.0
# Moree               113.0
# MountGambier         84.6
# MountGinini         107.6
# Newcastle           240.0
# Nhil                 65.6
# NorahHead           126.4
# NorfolkIsland       156.8
# Nuriootpa            76.6
# PearceRAAF           62.4
# Penrith             115.4
# Perth               114.4
# PerthAirport         76.6
# ...

# %%
albury = df.where(df['location'] == 'Albury')#15
albury
# Out:
#               date location  mintemp  maxtemp  rainfall windgustdir  \
# 0       01-12-2008   Albury     13.4     22.9       0.6           W
# 1       02-12-2008   Albury      7.4     25.1       0.0         WNW
# 2       03-12-2008   Albury     12.9     25.7       0.0         WSW
# 3       04-12-2008   Albury      9.2     28.0       0.0          NE
# 4       05-12-2008   Albury     17.5     32.3       1.0           W
# ...            ...      ...      ...      ...       ...         ...
# 145455         NaN      NaN      NaN      NaN       NaN         NaN
# 145456         NaN      NaN      NaN      NaN       NaN         NaN
# 145457         NaN      NaN      NaN      NaN       NaN         NaN
# 145458         NaN      NaN      NaN      NaN       NaN         NaN
# 145459         NaN      NaN      NaN      NaN       NaN         NaN
#
#         windgustspeed winddir9am winddir3pm  windspeed9am  ...  humidity3pm  \
# ...

# %%
albury.sort_values(by = ['maxtemp'],ascending= False)
# Out:
#               date location  mintemp  maxtemp  rainfall windgustdir  \
# 68      07-02-2009   Albury     22.3     44.8       0.0         NNW
# 2904    10-02-2017   Albury     23.0     43.7       0.0         WSW
# 1783    16-01-2014   Albury     23.0     43.6       0.0           N
# 1435    05-01-2013   Albury     19.8     43.4       0.0          NW
# 62      01-02-2009   Albury     28.0     43.1       0.0          SW
# ...            ...      ...      ...      ...       ...         ...
# 145455         NaN      NaN      NaN      NaN       NaN         NaN
# 145456         NaN      NaN      NaN      NaN       NaN         NaN
# 145457         NaN      NaN      NaN      NaN       NaN         NaN
# 145458         NaN      NaN      NaN      NaN       NaN         NaN
# 145459         NaN      NaN      NaN      NaN       NaN         NaN
#
#         windgustspeed winddir9am winddir3pm  windspeed9am  ...  humidity3pm  \
# ...

# %%
df.isna().sum()#16
# Out:
# date                 0
# location             0
# mintemp           1485
# maxtemp           1261
# rainfall          3261
# windgustdir      10326
# windgustspeed    10263
# winddir9am       10566
# winddir3pm        4228
# windspeed9am      1767
# windspeed3pm      3062
# humidity9am       2654
# humidity3pm       4507
# pressure9am      15065
# pressure3pm      15028
# cloud9am         55888
# cloud3pm         59358
# temp9am           1767
# temp3pm           3609
# raintoday         3261
# raintomorrow      3267
# difference        1881
# dtype: int64

# %%
df.dropna(subset = ['windgustdir'])#17
# Out:
#               date location  mintemp  maxtemp  rainfall windgustdir  \
# 0       01-12-2008   Albury     13.4     22.9       0.6           W
# 1       02-12-2008   Albury      7.4     25.1       0.0         WNW
# 2       03-12-2008   Albury     12.9     25.7       0.0         WSW
# 3       04-12-2008   Albury      9.2     28.0       0.0          NE
# 4       05-12-2008   Albury     17.5     32.3       1.0           W
# ...            ...      ...      ...      ...       ...         ...
# 145454  20-06-2017    Uluru      3.5     21.8       0.0           E
# 145455  21-06-2017    Uluru      2.8     23.4       0.0           E
# 145456  22-06-2017    Uluru      3.6     25.3       0.0         NNW
# 145457  23-06-2017    Uluru      5.4     26.9       0.0           N
# 145458  24-06-2017    Uluru      7.8     27.0       0.0          SE
#
#         windgustspeed winddir9am winddir3pm  windspeed9am  ...  humidity3pm  \
# ...

# %%
de = data.copy()

# %%
de.set_index('Location', inplace=True)#18

# %%
de['Evaporation'].min(),de['Evaporation'].max(),de['Evaporation'].median()
# Out:
# (0.0, 145.0, 4.8)

# %%
de['Sunshine'].min(),de['Sunshine'].max(),de['Sunshine'].median()
# Out:
# (0.0, 14.5, 8.4)

# %%
dx = data.copy()

# %%
#city_and_max_temp = dx.groupby('Location').agg('max')[['MaxTemp']].where(dx['Location']=='Perth')

# %%
#dx.merge( right=city_and_max_temp ,how='inner')[['Location','Date']]

# %%
a =dx.where(dx['Location']=='Perth').dropna()#19
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 120639  2008-07-02    Perth      6.4     20.7       0.0          1.8
# 120641  2008-07-04    Perth      9.5     19.2       1.8          1.2
# 120642  2008-07-05    Perth      9.5     16.4       1.8          1.4
# 120643  2008-07-06    Perth      0.7     15.9       6.8          2.4
# 120644  2008-07-07    Perth      0.7     18.3       0.0          0.8
# ...            ...      ...      ...      ...       ...          ...
# 123826  2017-06-21    Perth     10.3     19.9       0.2          1.8
# 123827  2017-06-22    Perth     13.0     16.8      61.2          3.6
# 123828  2017-06-23    Perth     13.3     18.9       0.4          1.8
# 123829  2017-06-24    Perth     11.5     18.2       0.0          3.8
# 123830  2017-06-25    Perth      6.3     17.0       0.0          1.6
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
a.groupby('Date').agg({'MaxTemp':'max'}).head(1)
# Out:
#             MaxTemp
# Date
# 2008-07-02     20.7

# %%
de.groupby('Location').apply(np.mean, axis=0)#20
# Out:
# Location
# Adelaide  MinTemp          12.579505
#           MaxTemp          22.898934
#           Rainfall          1.566354
#           Evaporation       5.770364
#           Sunshine          7.747993
#                             ...
# Woomera   Pressure3pm    1015.969917
#           Cloud9am          2.518027
#           Cloud3pm          2.891489
#           Temp9am          17.924701
#           Temp3pm          25.201896
# Length: 786, dtype: float64

# %%
de.groupby('Location').apply(np.mean, axis=1)
# Out:
# Location
# Adelaide  96320     166.585714
#           96321     164.478571
#           96322     162.335714
#           96323     162.600000
#           96324     174.307692
#                        ...
# Woomera   108566    159.135714
#           108567    151.020000
#           108568    151.046667
#           108569    162.257143
#           108570    187.466667
# Length: 145460, dtype: float64
