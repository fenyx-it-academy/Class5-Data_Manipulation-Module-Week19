# %%
import pandas as pd
import numpy as np
import datetime

# %% [markdown]
# # 1- Read the csv

# %%
data = pd.read_csv('weatherAUS.csv')
df = data.copy()
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %% [markdown]
# # 2- Find out the describe and info attributes of the dataframe.

# %%
df.describe().T
# Out:
#                   count         mean        std    min     25%     50%  \
# MinTemp        143975.0    12.194034   6.398495   -8.5     7.6    12.0
# MaxTemp        144199.0    23.221348   7.119049   -4.8    17.9    22.6
# Rainfall       142199.0     2.360918   8.478060    0.0     0.0     0.0
# Evaporation     82670.0     5.468232   4.193704    0.0     2.6     4.8
# Sunshine        75625.0     7.611178   3.785483    0.0     4.8     8.4
# WindGustSpeed  135197.0    40.035230  13.607062    6.0    31.0    39.0
# WindSpeed9am   143693.0    14.043426   8.915375    0.0     7.0    13.0
# WindSpeed3pm   142398.0    18.662657   8.809800    0.0    13.0    19.0
# Humidity9am    142806.0    68.880831  19.029164    0.0    57.0    70.0
# Humidity3pm    140953.0    51.539116  20.795902    0.0    37.0    52.0
# Pressure9am    130395.0  1017.649940   7.106530  980.5  1012.9  1017.6
# Pressure3pm    130432.0  1015.255889   7.037414  977.1  1010.4  1015.2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %% [markdown]
# # 3- Shape and size

# %%
df.size
# Out:
# 3345580

# %%
df.shape
# Out:
# (145460, 23)

# %% [markdown]
# # 4- Find out the type of values of the columns and save it as a dataframe.

# %%
types = pd.DataFrame(df.dtypes,columns = ['Types'])
types
# Out:
#                  Types
# Date            object
# Location        object
# MinTemp        float64
# MaxTemp        float64
# Rainfall       float64
# Evaporation    float64
# Sunshine       float64
# WindGustDir     object
# WindGustSpeed  float64
# WindDir9am      object
# WindDir3pm      object
# WindSpeed9am   float64
# WindSpeed3pm   float64
# Humidity9am    float64
# Humidity3pm    float64
# Pressure9am    float64
# Pressure3pm    float64
# Cloud9am       float64
# Cloud3pm       float64
# Temp9am        float64
# Temp3pm        float64
# RainToday       object
# RainTomorrow    object

# %% [markdown]
# # 5- Find out of the non-null counts of the columns and save the results as a dataframe.

# %%
non_null = pd.DataFrame(df.notnull().sum(),columns = ['The number of non-nulls'])
non_null
# Out:
#                The number of non-nulls
# Date                            145460
# Location                        145460
# MinTemp                         143975
# MaxTemp                         144199
# Rainfall                        142199
# Evaporation                      82670
# Sunshine                         75625
# WindGustDir                     135134
# WindGustSpeed                   135197
# WindDir9am                      134894
# WindDir3pm                      141232
# WindSpeed9am                    143693
# WindSpeed3pm                    142398
# Humidity9am                     142806
# Humidity3pm                     140953
# Pressure9am                     130395
# Pressure3pm                     130432
# Cloud9am                         89572
# Cloud3pm                         86102
# Temp9am                         143693
# Temp3pm                         141851
# RainToday                       142199
# RainTomorrow                    142193

# %% [markdown]
# # 6- Find out of the null counts of the columns and save the results as a dataframe.

# %%
null = pd.DataFrame(df.isnull().sum(),columns = ['The number of nulls'])
null
# Out:
#                The number of nulls
# Date                             0
# Location                         0
# MinTemp                       1485
# MaxTemp                       1261
# Rainfall                      3261
# Evaporation                  62790
# Sunshine                     69835
# WindGustDir                  10326
# WindGustSpeed                10263
# WindDir9am                   10566
# WindDir3pm                    4228
# WindSpeed9am                  1767
# WindSpeed3pm                  3062
# Humidity9am                   2654
# Humidity3pm                   4507
# Pressure9am                  15065
# Pressure3pm                  15028
# Cloud9am                     55888
# Cloud3pm                     59358
# Temp9am                       1767
# Temp3pm                       3609
# RainToday                     3261
# RainTomorrow                  3267

# %% [markdown]
# # 7- Find out the unique counts of the columns and save it as a dataframe.

# %%
unique = pd.DataFrame(df.nunique(),columns = ['The number of uniques'])
unique
# Out:
#                The number of uniques
# Date                            3436
# Location                          49
# MinTemp                          389
# MaxTemp                          505
# Rainfall                         681
# Evaporation                      358
# Sunshine                         145
# WindGustDir                       16
# WindGustSpeed                     67
# WindDir9am                        16
# WindDir3pm                        16
# WindSpeed9am                      43
# WindSpeed3pm                      44
# Humidity9am                      101
# Humidity3pm                      101
# Pressure9am                      546
# Pressure3pm                      549
# Cloud9am                          10
# Cloud3pm                          10
# Temp9am                          441
# Temp3pm                          502
# RainToday                          2
# RainTomorrow                       2

# %% [markdown]
# # 8- Merge the dataframes created in questions 4,5,6,7

# %%
pd.concat([types,non_null,null,unique],axis=1)
# Out:
#                  Types  The number of non-nulls  The number of nulls  \
# Date            object                   145460                    0
# Location        object                   145460                    0
# MinTemp        float64                   143975                 1485
# MaxTemp        float64                   144199                 1261
# Rainfall       float64                   142199                 3261
# Evaporation    float64                    82670                62790
# Sunshine       float64                    75625                69835
# WindGustDir     object                   135134                10326
# WindGustSpeed  float64                   135197                10263
# WindDir9am      object                   134894                10566
# WindDir3pm      object                   141232                 4228
# WindSpeed9am   float64                   143693                 1767
# WindSpeed3pm   float64                   142398                 3062
# ...

# %% [markdown]
# # 9- Lowercase all column names

# %%
df.columns = df.columns.str.lower()
df.columns
# Out:
# Index(['date', 'location', 'mintemp', 'maxtemp', 'rainfall', 'evaporation',
#        'sunshine', 'windgustdir', 'windgustspeed', 'winddir9am', 'winddir3pm',
#        'windspeed9am', 'windspeed3pm', 'humidity9am', 'humidity3pm',
#        'pressure9am', 'pressure3pm', 'cloud9am', 'cloud3pm', 'temp9am',
#        'temp3pm', 'raintoday', 'raintomorrow'],
#       dtype='object')

# %% [markdown]
# # 10- Change all No values to NoRain and all Yes values to Rain in raintoday and raintomorrow

# %%
df["raintoday"].replace({"Yes": "Rain", "No": "NoRain"}, inplace=True)
df["raintomorrow"].replace({"Yes": "Rain", "No": "NoRain"}, inplace=True)
df[['raintoday','raintomorrow']]
# Out:
#        raintoday raintomorrow
# 0         NoRain       NoRain
# 1         NoRain       NoRain
# 2         NoRain       NoRain
# 3         NoRain       NoRain
# 4         NoRain       NoRain
# ...          ...          ...
# 145455    NoRain       NoRain
# 145456    NoRain       NoRain
# 145457    NoRain       NoRain
# 145458    NoRain       NoRain
# 145459    NoRain          NaN
#
# [145460 rows x 2 columns]

# %% [markdown]
# # 11- Change the data type of 'date' (object) column to datetime64 DD/MM/YYYY

# %%
df['date'] = df['date'].map(lambda x: datetime.datetime.strptime(x, '%Y-%m-%d').strftime('%d-%m-%Y'))
df['date']
# Out:
# 0         01-12-2008
# 1         02-12-2008
# 2         03-12-2008
# 3         04-12-2008
# 4         05-12-2008
#              ...
# 145455    21-06-2017
# 145456    22-06-2017
# 145457    23-06-2017
# 145458    24-06-2017
# 145459    25-06-2017
# Name: date, Length: 145460, dtype: object

# %% [markdown]
# # 12- Create a new column called "difference", calculate the difference between maxtemp and mintemp columns for each row, and store the value in this new column.

# %%
df['difference'] = df['maxtemp']-df['mintemp']
df['difference'].head()
# Out:
# 0     9.5
# 1    17.7
# 2    12.8
# 3    18.8
# 4    14.8
# Name: difference, dtype: float64

# %% [markdown]
# # 13- Remove the evaporation and sunshine columns from the dataset permanently.

# %%
df_1 = df.drop(['evaporation','sunshine'], axis = 1) # inplace = True
df_1
# Out:
#               date location  mintemp  maxtemp  rainfall windgustdir  \
# 0       01-12-2008   Albury     13.4     22.9       0.6           W
# 1       02-12-2008   Albury      7.4     25.1       0.0         WNW
# 2       03-12-2008   Albury     12.9     25.7       0.0         WSW
# 3       04-12-2008   Albury      9.2     28.0       0.0          NE
# 4       05-12-2008   Albury     17.5     32.3       1.0           W
# ...            ...      ...      ...      ...       ...         ...
# 145455  21-06-2017    Uluru      2.8     23.4       0.0           E
# 145456  22-06-2017    Uluru      3.6     25.3       0.0         NNW
# 145457  23-06-2017    Uluru      5.4     26.9       0.0           N
# 145458  24-06-2017    Uluru      7.8     27.0       0.0          SE
# 145459  25-06-2017    Uluru     14.9      NaN       0.0         NaN
#
#         windgustspeed winddir9am winddir3pm  windspeed9am  ...  humidity3pm  \
# ...

# %% [markdown]
# # 14- Find out the most rainy day for each city.

# %%
most_rainy = df.loc[df.groupby('location')['rainfall'].idxmax().values][['location','date','rainfall']].set_index('location')
most_rainy
# Out:
#                         date  rainfall
# location
# Adelaide          14-02-2014      75.2
# Albany            02-06-2012      49.4
# Albury            01-03-2012     104.2
# AliceSprings      28-02-2010      62.0
# BadgerysCreek     29-01-2013     116.0
# Ballarat          14-01-2011      95.0
# Bendigo           05-02-2011      66.4
# Brisbane          02-05-2015     182.6
# Cairns            12-01-2009     278.4
# Canberra          03-12-2010      87.0
# Cobar             16-02-2014      68.0
# CoffsHarbour      07-11-2009     371.0
# Dartmoor          14-01-2011      73.6
# Darwin            16-02-2011     367.6
# GoldCoast         29-04-2012     183.4
# Hobart            14-01-2015      71.6
# Katherine         27-12-2015     167.0
# Launceston        29-01-2016      88.0
# Melbourne         07-02-2011      82.2
# MelbourneAirport  01-06-2013      75.8
# Mildura           05-02-2011     155.0
# Moree             26-11-2011     113.0
# MountGambier      14-01-2011      84.6
# ...

# %% [markdown]
# # 15- Filter out all the data for the city 'Albury' and then sort according to maxtemp column.

# %%
df[df['location']=='Albury'].sort_values(by = 'maxtemp', ascending = False)
# Out:
#             date location  mintemp  maxtemp  rainfall  evaporation  sunshine  \
# 68    07-02-2009   Albury     22.3     44.8       0.0          NaN       NaN
# 2904  10-02-2017   Albury     23.0     43.7       0.0          NaN       NaN
# 1783  16-01-2014   Albury     23.0     43.6       0.0          NaN       NaN
# 1435  05-01-2013   Albury     19.8     43.4       0.0          NaN       NaN
# 62    01-02-2009   Albury     28.0     43.1       0.0          NaN       NaN
# ...          ...      ...      ...      ...       ...          ...       ...
# 984   11-09-2011   Albury      NaN      NaN       NaN          NaN       NaN
# 985   12-09-2011   Albury      NaN      NaN       NaN          NaN       NaN
# 1529  07-05-2013   Albury      3.9      NaN       0.0          NaN       NaN
# 2031  21-09-2014   Albury      3.4      NaN       0.0          NaN       NaN
# 2032  22-09-2014   Albury      NaN      NaN       NaN          NaN       NaN
#
# ...

# %% [markdown]
# # 16- Find out the NaN counts for each column.

# %%
df.isnull().sum()
# Out:
# date                 0
# location             0
# mintemp           1485
# maxtemp           1261
# rainfall          3261
# evaporation      62790
# sunshine         69835
# windgustdir      10326
# windgustspeed    10263
# winddir9am       10566
# winddir3pm        4228
# windspeed9am      1767
# windspeed3pm      3062
# humidity9am       2654
# humidity3pm       4507
# pressure9am      15065
# pressure3pm      15028
# cloud9am         55888
# cloud3pm         59358
# temp9am           1767
# temp3pm           3609
# raintoday         3261
# raintomorrow      3267
# difference        1881
# dtype: int64

# %% [markdown]
# # 17- Remove the rows with NaN values in "windgustdir" column from the dataframe permanently.

# %%
df.dropna(subset = ['windgustdir'],inplace = True)
df.reset_index(inplace = True)
df
# Out:
#          index        date location  mintemp  maxtemp  rainfall  evaporation  \
# 0            0  01-12-2008   Albury     13.4     22.9       0.6          NaN
# 1            1  02-12-2008   Albury      7.4     25.1       0.0          NaN
# 2            2  03-12-2008   Albury     12.9     25.7       0.0          NaN
# 3            3  04-12-2008   Albury      9.2     28.0       0.0          NaN
# 4            4  05-12-2008   Albury     17.5     32.3       1.0          NaN
# ...        ...         ...      ...      ...      ...       ...          ...
# 135129  145454  20-06-2017    Uluru      3.5     21.8       0.0          NaN
# 135130  145455  21-06-2017    Uluru      2.8     23.4       0.0          NaN
# 135131  145456  22-06-2017    Uluru      3.6     25.3       0.0          NaN
# 135132  145457  23-06-2017    Uluru      5.4     26.9       0.0          NaN
# 135133  145458  24-06-2017    Uluru      7.8     27.0       0.0          NaN
#
# ...

# %% [markdown]
# # 18- Create a new dataframe, use "Location" column as the index of the dataframe, display the min, max, and median values of "evaporation" and "sunshine" columns in this dataframe.

# %%
location = df.groupby('location').agg({'sunshine':['min','max','median'],'evaporation':['min','max','median']})
location
# Out:
#                  sunshine              evaporation
#                       min   max median         min   max median
# location
# Adelaide              0.0  13.9    8.4         0.0  43.4    4.2
# Albury                NaN   NaN    NaN         NaN   NaN    NaN
# AliceSprings          0.0  13.4   10.6         0.0  50.2    8.2
# BadgerysCreek         NaN   NaN    NaN         NaN   NaN    NaN
# Ballarat              NaN   NaN    NaN         NaN   NaN    NaN
# Bendigo               NaN   NaN    NaN         0.0  15.4    3.1
# Brisbane              0.0  13.5    9.4         0.0  44.0    5.2
# Cairns                0.0  12.8    8.6         0.2  44.4    6.0
# Canberra              0.0  13.6    8.1         0.0  17.2    3.4
# Cobar                 0.0  13.7    9.9         0.0  86.2    5.6
# CoffsHarbour          0.0  13.8    8.5         0.0  19.8    3.6
# Dartmoor              0.0  14.3    6.4         0.0  16.4    2.6
# Darwin                0.0  12.3   10.0         0.2  19.2    6.4
# ...

# %% [markdown]
# # 19- Find out the hottest day of "Perth". Example output: Timestamp('2015-01-05 00:00:00')

# %%
perth = df[df['location']=='Perth']
pd.DataFrame(perth[perth['maxtemp']==perth['maxtemp'].max()]['date'])
# Out:
#               date
# 113043  05-01-2015

# %% [markdown]
# # 20- Group your dataframe by location and find out the averages of all numeric values.

# %%
df.groupby('location').mean().drop(['index'],axis = 1)
# Out:
#                     mintemp    maxtemp  rainfall  evaporation  sunshine  \
# location
# Adelaide          12.571487  22.891254  1.576076     5.757117  7.742417
# Albury             9.518588  22.629555  1.904552          NaN       NaN
# AliceSprings      13.155254  29.281325  0.869484     9.042405  9.592820
# BadgerysCreek     11.135741  24.014949  2.215406          NaN       NaN
# Ballarat           7.348670  18.267930  1.706369          NaN       NaN
# Bendigo            8.611841  21.625609  1.631586     3.835616       NaN
# Brisbane          16.414204  26.436043  3.119424     5.406064  8.069265
# Cairns            21.225099  29.559550  5.701852     6.244197  7.577948
# Canberra           6.670100  20.731579  1.745920     4.134289  7.419064
# Cobar             13.131412  25.853488  1.132655     6.751995  8.693236
# CoffsHarbour      14.522998  23.971493  4.990985     3.912857  7.353320
# Dartmoor           8.620518  19.696769  2.150272     3.354226  6.419215
# ...
